# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 201)
plt.plot(x, np.cos(x))
k=int(input('Введите К'))
plt.plot(x, np.cos(k*x))
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.show()
# Out:
# Введите К4
